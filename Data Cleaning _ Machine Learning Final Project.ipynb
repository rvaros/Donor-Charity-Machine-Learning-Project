# %%
# Import dependencies
import numpy as np
import pandas as pd
from time import time
from IPython.display import display
#import seaborn

# Pretty display for notebooks
# %matplotlib inline

# %%
# Load the Census dataset
data = pd.read_csv("census_cleaned.csv")

# Success - Display the first record
display(data.head(n=5))
#display(data['education-num'].unique())
# Out:
#    age          workclass education_level  education-num       marital-status  \
# 0   39          State-gov       Bachelors             13        Never-married
# 1   50   Self-emp-not-inc       Bachelors             13   Married-civ-spouse
# 2   38            Private         HS-grad              9             Divorced
# 3   53            Private            11th              7   Married-civ-spouse
# 4   28            Private       Bachelors             13   Married-civ-spouse
#
#            occupation    relationship    race  sex  capital-gain  \
# 0        Adm-clerical   Not-in-family   White    0          2174
# 1     Exec-managerial         Husband   White    0             0
# 2   Handlers-cleaners   Not-in-family   White    0             0
# 3   Handlers-cleaners         Husband   Black    0             0
# 4      Prof-specialty            Wife   Black    1             0
#
#    capital-loss  hours-per-week  native-country  income
# ...

# %%
# Drop any rows that have Nan values (how: drop whole row)
data.dropna(how='all')
# Out:
#        age          workclass education_level  education-num  \
# 0       39          State-gov       Bachelors             13
# 1       50   Self-emp-not-inc       Bachelors             13
# 2       38            Private         HS-grad              9
# 3       53            Private            11th              7
# 4       28            Private       Bachelors             13
# 5       37            Private         Masters             14
# 6       49            Private             9th              5
# 7       52   Self-emp-not-inc         HS-grad              9
# 8       31            Private         Masters             14
# 9       42            Private       Bachelors             13
# 10      37            Private    Some-college             10
# 11      30          State-gov       Bachelors             13
# 12      23            Private       Bachelors             13
# 13      32            Private      Assoc-acdm             12
# ...

# %%
# Load the Census dataset
test = pd.read_csv("test_census_cleaned.csv")

# Success - Display the first record
display(test.head(n=5))
# Out:
#    Unnamed: 0   age          workclass education_level  education-num  \
# 0           0  21.0            Private            10th            6.0
# 1           1  49.0            Private       Bachelors           13.0
# 2           2  44.0   Self-emp-not-inc      Assoc-acdm           12.0
# 3           3  34.0            Private       Bachelors           13.0
# 4           4  24.0            Private         HS-grad            9.0
#
#         marital-status          occupation relationship    race  sex  \
# 0   Married-civ-spouse        Craft-repair      Husband   White  0.0
# 1   Married-civ-spouse        Adm-clerical         Wife   White  1.0
# 2   Married-civ-spouse       Other-service         Wife   White  1.0
# 3   Married-civ-spouse               Sales      Husband   White  0.0
# 4   Married-civ-spouse   Machine-op-inspct      Husband   White  0.0
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0           0.0           0.0            40.0   United-States
# ...

# %%
# Drop any rows that have Nan values (how: drop whole row)
test.dropna(how='all')
# Out:
#        Unnamed: 0   age          workclass education_level  education-num  \
# 0               0  21.0            Private            10th            6.0
# 1               1  49.0            Private       Bachelors           13.0
# 2               2  44.0   Self-emp-not-inc      Assoc-acdm           12.0
# 3               3  34.0            Private       Bachelors           13.0
# 4               4  24.0            Private         HS-grad            9.0
# 5               5  52.0            Private         7th-8th            4.0
# 6               6  61.0            Private         7th-8th            4.0
# 7               7  24.0            Private         HS-grad            9.0
# 8               8  30.0            Private         HS-grad            9.0
# 9               9  42.0          Local-gov         HS-grad            9.0
# 10             10  47.0          Local-gov     Prof-school           15.0
# 11             11  42.0   Self-emp-not-inc       Bachelors           13.0
# ...

# %%
# compare the column names in data & test this is the real data CSV
list(data.columns.values)
# Out:
# ['age',
#  'workclass',
#  'education_level',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'income']

# %%
#List of column names in the test CSV
list(test.columns.values)
# Out:
# ['Unnamed: 0',
#  'age',
#  'workclass',
#  'education_level',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %%
#making a box plot to show any outliers in the test data so we can get rid of it. 
#we're specifically looking for outliers in the "capital-gain" and "capital-loss" columns
#because they're skewing that data

# seaborn.boxplot(x=test['capital-gain'])
#Nevermind, i apparently don't have seaborn anymore, ugh.

# %%
#trying to get rid of outliers here?
#def reject_outliers(test, m=2):
#    return data[abs(data - np.mean(data)) < m * np.std(test)]

# %%
# Begin linear regression
# Assign the data to X and y

X = test[["education-num", "sex"]]
y = test["age"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (45222, 2) (45222, 1)

# %%
 # Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-307baa1eb026> in <module>
#       2
#       3 ### BEGIN SOLUTION
# ----> 4 model.fit(X_train, y_train)
#       5 training_score = model.score(X_train, y_train)
#       6 testing_score = model.score(X_test, y_test)
#
# /anaconda3/envs/CWRU/lib/python3.7/site-packages/sklearn/linear_model/base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...
